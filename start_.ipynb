# %%
import os
import sys
os.environ["this_python"] = sys.executable  # get the right python executable

# %%
# !$this_python -u start_nosinn.py \
--dataset celeba \
--levels 3 \
--level-depth 8 \
--reshape-method haar \
--glow False \
--batch-norm False \
--coupling-channels 512 \
--val-freq 10 \
--autoencode True \
--use-wandb False \
--zs-frac 0.01 \
--path-to-ae /mnt/archive/fairness/NoSINN/experiments/finn/1572884064.8234699/latest_checkpt.pth \
--quant-level 8 \
--input-noise False \
--nll-weight 1e1 \
--ae-levels 3 \
--ae-channels 64 \
--ae-enc-dim 16 \
--vae True \
--train-on-recon False \
--pred-s-weight 1 \
--disc-channels 512 \
--lr 3e-4 \
--disc-lr 3e-4 \
--weight-decay 0 \
--epochs 30 \
--super-val True \
--eval-epochs 5 \
--val-freq 5 \
--disc-channels 512 \
--train-on-recon True \
--pred-s-weight 1 \
--recon-stability 1 \
--input-noise False \
--gpu 0 \
--epochs 2 \
--resume /mnt/archive/fairness/NoSINN/celeba_final_checkpt.pth \
--feat-attr True \
--eval-epochs 80 \
--data-pcnt 1 \
--seed 102382
# --ae-channels 61 \
# --ae-enc-dim 35 \
# --ae-epochs 60 \
# --ae-levels 0 \
# --ae-loss mixed \
# --autoencode True \
# --batch-norm False \
# --batch-size 1000 \
# --coupling-channels 20 \
# --coupling-depth 1 \
# --dataset adult \
# --disc-hidden-dims 256 \
# --disc-lr 3e-4 \
# --drop-native True \
# --epochs 20 \
# --gamma 0.96 \
# --glow True \
# --input-noise False \
# --level-depth 1 \
# --lr 1e-3 \
# --nll-weight 1 \
# --pred-s-weight 3e-3 \
# --scaling add2_sigmoid \
# --super-val True \
# --task-mixing-factor 0.0 \
# --train-on-recon True \
# --vae False \
# --val-freq 20 \
# --weight-decay 1e-6 \
# --zs-frac 0.03
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# /mnt/archive/fairness/NoSINN/nosinn/optimisation/train_nosinn.py
# Namespace(ae_channels=64, ae_enc_dim=16, ae_epochs=5, ae_levels=3, ae_loss=l2, ae_loss_weight=1, autoencode=True, background=False, base_density=normal, base_density_std=1, batch_norm=False, batch_size=128, binarize=True, black=True, bn_lag=0, celeba_sens_attr=['Male'], celeba_target_attr=Smiling, coupling_channels=512, coupling_depth=1, data_pcnt=1.0, data_split_seed=888, dataset=celeba, disc_channels=512, disc_depth=1, disc_hidden_dims=[], disc_lr=0.0003, drop_discrete=False, drop_native=True, early_stopping=30, epochs=2, eval_epochs=80, eval_lr=0.001, evaluate=False, factor_splits={}, feat_attr=True, gamma=1.0, glow=False, gp_weight=0, gpu=0, greyscale=False, idf=False, input_noise=False, kl_weight=0.1, level_depth=8, levels=3, log_freq=50, lr=0.0003, nll_weight=10.0, padding=2, path_to_ae=/mnt/archive/fairness/NoSINN/experiments/finn/1572884064.8234699/latest_checkpt.pth, pred_s_weight=1.0, preliminary_level=False, pretrain=True, pretrain_pcnt=0.4, quant_level=8, recon_detach=True, recon_stability_weight=1.0, reshape_method=haar, results_csv=, resume=/mnt/archive/fairness/NoSINN/celeba_final_checkpt.pth, root=data, rotate_data=False, save_dir=experiments/finn, scale=0.02, scaling=sigmoid0.5, seed=102382, shift_data=False, spectral_norm=False, super_val=True, task_mixing_factor=0.0, task_pcnt=0.2, test_batch_size=None, train_on_recon=True, use_wandb=False, vae=True, val_freq=5, warmup_steps=0, weight_decay=0.0, zs_frac=0.01)
# Save directory: /mnt/archive/fairness/NoSINN/experiments/finn/1576251495.0207524
# 2 GPUs available. Using device 'cuda:0'
# Size of pretrain: 81039, task_train: 35174, task: 40520
# zs dim: 10
# zy dim: 1014
# Restoring model from checkpoint
# Encoding task dataset...
# ^C
# Traceback (most recent call last):
#   File "start_nosinn.py", line 4, in <module>
#     main_nosinn()
#   File "/mnt/archive/fairness/NoSINN/nosinn/optimisation/train_nosinn.py", line 424, in main_nosinn
#     ARGS, model=inn, data=datasets, save_to_csv=Path(ARGS.save_dir), step=0, feat_attr=ARGS.feat_attr
#   File "/mnt/archive/fairness/NoSINN/nosinn/optimisation/evaluation.py", line 47, in log_metrics
#     task_repr = encode_dataset(args, data.task, model, recon=True, subdir="task")
#   File "/mnt/archive/fairness/NoSINN/nosinn/optimisation/evaluation.py", line 331, in encode_dataset
#     for _, (x, s, y) in enumerate(data):
#   File "/opt/tljh/user/envs/pytorch/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 346, in __next__
#     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#   File "/opt/tljh/user/envs/pytorch/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py", line 44, in fetch
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/opt/tljh/user/envs/pytorch/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py", line 44, in <listcomp>
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/opt/tljh/user/envs/pytorch/lib/python3.7/site-packages/torch/utils/data/dataset.py", line 257, in __getitem__
#     return self.dataset[self.indices[idx]]
#   File "/mnt/archive/fairness/NoSINN/nosinn/data/celeba.py", line 182, in __getitem__
#     X = self.transform(X)
#   File "/opt/tljh/user/envs/pytorch/lib/python3.7/site-packages/torchvision/transforms/transforms.py", line 70, in __call__
#     img = t(img)
#   File "/opt/tljh/user/envs/pytorch/lib/python3.7/site-packages/torchvision/transforms/transforms.py", line 207, in __call__
#     return F.resize(img, self.size, self.interpolation)
#   File "/opt/tljh/user/envs/pytorch/lib/python3.7/site-packages/torchvision/transforms/functional.py", line 249, in resize
#     return img.resize((ow, oh), interpolation)
#   File "/opt/tljh/user/envs/pytorch/lib/python3.7/site-packages/PIL/Image.py", line 1886, in resize
#     self.load()
#   File "/opt/tljh/user/envs/pytorch/lib/python3.7/site-packages/PIL/ImageFile.py", line 253, in load
#     n, err_code = decoder.decode(b)
# KeyboardInterrupt
