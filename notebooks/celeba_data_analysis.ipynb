# %%
from pathlib import Path
import pandas as pd

# %%
base = Path("..") / "data" / "celeba"
raw_attr = pd.read_csv(base / "list_attr_celeba.txt", delim_whitespace=True, header=1)

# %%
raw_attr
# Out:
#             5_o_Clock_Shadow  Arched_Eyebrows  Attractive  Bags_Under_Eyes  \
# 000001.jpg                -1                1           1               -1
# 000002.jpg                -1               -1          -1                1
# 000003.jpg                -1               -1          -1               -1
# 000004.jpg                -1               -1           1               -1
# 000005.jpg                -1                1           1               -1
# ...                      ...              ...         ...              ...
# 202595.jpg                -1               -1           1               -1
# 202596.jpg                -1               -1          -1               -1
# 202597.jpg                -1               -1          -1               -1
# 202598.jpg                -1                1           1               -1
# 202599.jpg                -1                1           1               -1
#
# ...

# %%
raw_attr.columns
# Out:
# Index(['5_o_Clock_Shadow', 'Arched_Eyebrows', 'Attractive', 'Bags_Under_Eyes',
#        'Bald', 'Bangs', 'Big_Lips', 'Big_Nose', 'Black_Hair', 'Blond_Hair',
#        'Blurry', 'Brown_Hair', 'Bushy_Eyebrows', 'Chubby', 'Double_Chin',
#        'Eyeglasses', 'Goatee', 'Gray_Hair', 'Heavy_Makeup', 'High_Cheekbones',
#        'Male', 'Mouth_Slightly_Open', 'Mustache', 'Narrow_Eyes', 'No_Beard',
#        'Oval_Face', 'Pale_Skin', 'Pointy_Nose', 'Receding_Hairline',
#        'Rosy_Cheeks', 'Sideburns', 'Smiling', 'Straight_Hair', 'Wavy_Hair',
#        'Wearing_Earrings', 'Wearing_Hat', 'Wearing_Lipstick',
#        'Wearing_Necklace', 'Wearing_Necktie', 'Young'],
#       dtype='object')

# %%
((raw_attr[["Black_Hair", "Blond_Hair", "Brown_Hair", "Gray_Hair", "Bald"]] + 1) // 2).sum(axis="columns").value_counts()
# Out:
# 1    124892
# 0     73619
# 2      4083
# 3         5
# dtype: int64

# %%
((raw_attr[["Black_Hair", "Blond_Hair", "Brown_Hair", "Gray_Hair", "Bald", "Wearing_Hat"]] + 2) // 2).sum(axis="columns").value_counts()
# Out:
# 1    132725
# 0     64794
# 2      5074
# 3         6
# dtype: int64

# %%
def _nice_print(row):
    return f"black: {row[0]}, blond: {row[1]}, brown: {row[2]}, gray: {row[3]}, bald: {row[4]}"
((raw_attr[["Black_Hair", "Blond_Hair", "Brown_Hair", "Gray_Hair", "Bald", "Wearing"]] + 2) // 2).agg(_nice_print, axis="columns").value_counts()
# Out:
# black: 0, blond: 0, brown: 0, gray: 0, bald: 0    73619
# black: 1, blond: 0, brown: 0, gray: 0, bald: 0    47264
# black: 0, blond: 0, brown: 1, gray: 0, bald: 0    39165
# black: 0, blond: 1, brown: 0, gray: 0, bald: 0    28251
# black: 0, blond: 0, brown: 0, gray: 1, bald: 0     6828
# black: 0, blond: 0, brown: 0, gray: 0, bald: 1     3384
# black: 0, blond: 1, brown: 1, gray: 0, bald: 0     1216
# black: 1, blond: 0, brown: 1, gray: 0, bald: 0     1136
# black: 0, blond: 0, brown: 0, gray: 1, bald: 1     1100
# black: 0, blond: 1, brown: 0, gray: 1, bald: 0      508
# black: 1, blond: 0, brown: 0, gray: 0, bald: 1       59
# black: 0, blond: 0, brown: 1, gray: 1, bald: 0       48
# black: 1, blond: 0, brown: 0, gray: 1, bald: 0       10
# black: 0, blond: 1, brown: 1, gray: 1, bald: 0        4
# black: 1, blond: 1, brown: 0, gray: 0, bald: 0        3
# black: 0, blond: 0, brown: 1, gray: 0, bald: 1        2
# black: 0, blond: 1, brown: 0, gray: 0, bald: 1        1
# ...

# %%
raw_attr.loc[((raw_attr[["Black_Hair", "Blond_Hair", "Brown_Hair", "Gray_Hair", "Bald"]] + 2) // 2).sum(axis="columns") >2]
# Out:
#             5_o_Clock_Shadow  Arched_Eyebrows  Attractive  Bags_Under_Eyes  \
# 010787.jpg                -1               -1          -1               -1
# 051764.jpg                -1               -1          -1               -1
# 068155.jpg                -1               -1          -1                1
# 084881.jpg                -1               -1          -1                1
# 147957.jpg                -1               -1          -1               -1
#
#             Bald  Bangs  Big_Lips  Big_Nose  Black_Hair  Blond_Hair  ...  \
# 010787.jpg    -1     -1        -1        -1          -1           1  ...
# 051764.jpg    -1     -1        -1        -1          -1           1  ...
# 068155.jpg    -1     -1        -1        -1          -1           1  ...
# 084881.jpg     1     -1        -1        -1          -1          -1  ...
# 147957.jpg    -1     -1        -1        -1          -1           1  ...
#
# ...

# %%
# def _nice_print(row):
#     return f"black: {row[0]}, blond: {row[1]}, brown: {row[2]}, gray: {row[3]}, bald: {row[4]}"
# ((raw_attr[["Black_Hair", "Blond_Hair", "Brown_Hair", "Gray_Hair", "Bald", "Wearing"]] + 2) // 2).agg(_nice_print, axis="columns").value_counts()
just_hair = raw_attr[["Black_Hair", "Blond_Hair", "Brown_Hair", "Gray_Hair", "Bald"]]
just_hair.columns = list(range(5))
just_hair.idxmax(axis="columns")
# Out:
# 000001.jpg    2
# 000002.jpg    2
# 000003.jpg    0
# 000004.jpg    0
# 000005.jpg    0
#              ..
# 202595.jpg    1
# 202596.jpg    1
# 202597.jpg    0
# 202598.jpg    0
# 202599.jpg    1
# Length: 202599, dtype: int64

# %%
((raw_attr[["Black_Hair", "Blond_Hair", "Brown_Hair", "Gray_Hair", "Bald"]] + 2) // 2).melt(axis="columns")

# %%
raw_attr
# Out:
#             5_o_Clock_Shadow  Arched_Eyebrows  Attractive  Bags_Under_Eyes  \
# 000001.jpg                -1                1           1               -1
# 000002.jpg                -1               -1          -1                1
# 000003.jpg                -1               -1          -1               -1
# 000004.jpg                -1               -1           1               -1
# 000005.jpg                -1                1           1               -1
# ...                      ...              ...         ...              ...
# 202595.jpg                -1               -1           1               -1
# 202596.jpg                -1               -1          -1               -1
# 202597.jpg                -1               -1          -1               -1
# 202598.jpg                -1                1           1               -1
# 202599.jpg                -1                1           1               -1
#
# ...

# %%
print(", ".join(["Black_Hair", "Blond_Hair", "Brown_Hair", "Gray_Hair", "Bald", "Wearing"]))
# Out:
# Black_Hair, Blond_Hair, Brown_Hair, Gray_Hair, Bald, Wearing
