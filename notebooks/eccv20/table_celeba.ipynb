# %%
import pandas as pd

# %%
gender_files = {
#     "cFlow20": "../../experiments/finn/celeba_xy_y_on_recons_rosy-feather-more-eval.csv",
    "cFlow": "../../experiments/finn/celeba_xy_y_on_recons_rosy-feather-epoch60-more-eval.csv",
#     "cFlow140": "../../experiments/finn/celeba_xy_y_on_recons_rosy-feather-epoch140-more-eval.csv",
    "cVAE": "../../experiments/vae/celeba_xy_y_on_recons_gender_more_eval.csv",
    "CNN": "../../experiments/baseline/celeba_naive_baseline_Male_Smiling_40epochs.csv",
    "Kim et al.": "../../experiments/ln2l/celeba_ln2l_Smiling_0.01ew_40epochs_gender_more_eval.csv",
}

# %%
def read(file_dict):
    df = pd.DataFrame()
    for method, fname in file_dict.items():
        data = pd.read_csv(fname)
        data["method"] = method
        df = pd.concat([df, data], axis="index", sort=False, ignore_index=True)
    return df

# %%
gender = read(gender_files)

# %%
gender
# Out:
#    Mix_fact  Accuracy  prob_pos       TPR       TNR       PPV  \
# 0       0.0  0.831343  0.501925  0.845371  0.818264  0.812617
# 1       1.0  0.819645  0.495903  0.827008  0.812780  0.804618
# 2       0.0  0.820262  0.501654  0.836394  0.805461  0.797757
# 3       1.0  0.809946  0.475642  0.798432  0.820509  0.803196
# 4       0.0  0.606441  0.418781  0.526357  0.679917  0.601391
# 5       1.0  0.673988  0.579812  0.765216  0.590290  0.631480
# 6       0.0  0.521520  0.000000  0.000000  1.000000       NaN
# 7       1.0  0.509378  0.747483  0.768413  0.271721  0.491878
#
#    Renyi preds and s  Accuracy_sens_0.0  Accuracy_sens_1.0  \
# 0           0.101733           0.859164           0.792529
# 1           0.330370           0.826159           0.810557
# 2           0.047367           0.847408           0.782578
# 3           0.157082           0.815947           0.801615
# 4           0.627581           0.610835           0.600342
# ...

# %%
rename_dict = {
    "method": "Method",
    "Accuracy": "Accuracy",
    "prob_pos_sens_0.0-sens_1.0": "DP diff",
    "TPR_sens_0.0-sens_1.0": "TPR diff",
    "TNR_sens_0.0-sens_1.0": "TNR diff",
}
table1 = gender.query("Mix_fact == 0")[list(rename_dict)].rename(columns=rename_dict).reset_index(drop=True)
table1 = table1.round(2)
table1
# Out:
#        Method  Accuracy  DP diff  TPR diff  TNR diff
# 0       cFlow      0.83     0.10      0.15      0.25
# 1        cVAE      0.82     0.05      0.09      0.18
# 2         CNN      0.61     0.63      0.70      0.64
# 3  Kim et al.      0.52     0.00      0.00      0.00

# %%
print(table1.to_latex(index=False, escape=False))
# Out:
# \begin{tabular}{lrrrr}
# \toprule
#      Method &  Accuracy &  DP diff &  TPR diff &  TNR diff \\
# \midrule
#       cFlow &      0.83 &     0.10 &      0.15 &      0.25 \\
#        cVAE &      0.82 &     0.05 &      0.09 &      0.18 \\
#         CNN &      0.61 &     0.63 &      0.70 &      0.64 \\
#  Kim et al. &      0.52 &     0.00 &      0.00 &      0.00 \\
# \bottomrule
# \end{tabular}

# %%
table2 = gender.query("Mix_fact == 1")[list(rename_dict)].rename(columns=rename_dict).reset_index(drop=True)
table2 = table2.round(2)
table2
# Out:
#        Method  Accuracy  DP diff  TPR diff  TNR diff
# 0       cFlow      0.82     0.33      0.28      0.21
# 1        cVAE      0.81     0.16      0.10      0.05
# 2         CNN      0.67     0.75      0.66      0.76
# 3  Kim et al.      0.51     0.08      0.06      0.09

# %%
print(table2.to_latex(index=False, escape=False))
# Out:
# \begin{tabular}{lrrrr}
# \toprule
#      Method &  Accuracy &  DP diff &  TPR diff &  TNR diff \\
# \midrule
#       cFlow &      0.82 &     0.33 &      0.28 &      0.21 \\
#        cVAE &      0.81 &     0.16 &      0.10 &      0.05 \\
#         CNN &      0.67 &     0.75 &      0.66 &      0.76 \\
#  Kim et al. &      0.51 &     0.08 &      0.06 &      0.09 \\
# \bottomrule
# \end{tabular}
