# %%
from plotting_helpers import nice_plot, from_default_place

# %%
results = {
    "recon, AE-levels 2, huber": from_default_place("xy_recon_aelevels2_huber.csv"),
}

# %%
plot = nice_plot(results, x_axis=("Scale", "scale"), y_axis=("Accuracy", "accuracy"), title="CMNIST, INN with AE")
plot.grid(False)
