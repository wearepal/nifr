# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
import torch

# %%
xi = torch.randn(100, 16, 8, 8)
xi = torch.flatten(xi, start_dim=1)

# %%
cols = 3
rows = 11
fig, plots = plt.subplots(figsize=(8, 12), ncols=cols, nrows=rows)
# fig.suptitle("Xi histogram")
for j in range(rows):
    for i in range(cols):
        _ = plots[j][i].hist(xi[:, j * cols + i], bins=np.linspace(-3, 3, 6))
# fig.tight_layout()
