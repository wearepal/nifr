# %%
from pathlib import Path
import pandas as pd
from plotting_helpers import from_default_place, nice_plot

# %%
results = {
    "CVPR20": from_default_place("celeba_inn_cvpr20.csv"),
    "xi penalty": from_default_place("xy_y_on_recons_xi_penalty.csv"),
}

# %%
nice_plot(results, "Accuracy")

# %%
nice_plot(results, ("prob_pos_sex_Male_0.0-sex_Male_1.0", "Fairness"))

# %%
rosy_firebrand = {
#     "epoch 40": from_default_place("celeba_xy_y_on_recons_rosy_firebrand_epoch_40.csv"),
#     "epoch 80": from_default_place("celeba_xy_y_on_recons_rosy-firebrand_epoch_80.csv"),
#     "CVPR20": pd.read_csv(Path("cvpr20") / "celeba_inn.csv"),
    "epoch 20": from_default_place("celeba_xy_y_on_recons_rosy_firebrand_epoch_20.csv"),
    "epoch 10": from_default_place("celeba_xy_y_on_recons_rosy_firebrand_epoch_10.csv"),
#     "K&C": from_default_place("celeba_kamiran_baseline_Male_Smiling_40epochs.csv"),
#     "CNN": pd.read_csv(Path("cvpr20") / "celeba_naive_baseline_pred_y_25epochs.csv"),
#     "half the zs_dim": from_default_place("celeba_xy_y_on_recons_autumn_sun_epoch_20.csv"),
#     "Ln2l": pd.read_csv(Path("cvpr20") / "celeba_5kims_Male_Smiling_0.01ew_40epochs.csv"),
    "treasure, 20": pd.read_csv("celeba_xy_y_on_recons_treasured-planet-1458-epoch20.csv"),
    "treasure, 30": pd.read_csv("celeba_xy_y_on_recons_treasured-planet-1458-epoch30.csv"),
}

# %%
nice_plot(rosy_firebrand, "Accuracy", i_hate_fun=True, no_lines=True, figsize=(6, 4))

# %%
nice_plot(rosy_firebrand, ("prob_pos_sex_Male_0.0-sex_Male_1.0", "DP diff"), i_hate_fun=True, no_lines=True, figsize=(6, 4))

# %%
nice_plot(rosy_firebrand, ("TPR_sex_Male_0.0-sex_Male_1.0", "TPR diff"), i_hate_fun=True, no_lines=True, figsize=(6, 4))
